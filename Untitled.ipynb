# %%
# %matplotlib notebook

import sys ; sys.path.append('..')
# %run -i streamstd.py
# %run -i algo1.py
# Out:
# /opt/conda/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
f.axes[0].set_ylim(-30,37)

f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7149a7f82d8c> in <module>()
# ----> 1 f.axes[0].set_ylim(-30,37)
#       2
#       3 f
#
# NameError: name 'f' is not defined

# %%
st.norm.cdf(1)

# %%
df.tail(100)
# Out:
#              o     ratio  t_rolling_mean  t_rolling_std  tavg  tstd         u  \
# 4900  4.115094  0.000000               1              1     1     1  7.278326
# 4901  4.115645  0.000000               1              1     1     1  7.273367
# 4902  4.115652  0.000000               1              1     1     1  7.272821
# 4903  4.116086  0.000000               1              1     1     1  7.268462
# 4904  4.117445  0.000000               1              1     1     1  7.260791
# 4905  4.117943  0.000000               1              1     1     1  7.256166
# 4906  4.118545  0.000000               1              1     1     1  7.251113
# 4907  4.119750  0.000000               1              1     1     1  7.243996
# 4908  4.120496  0.000000               1              1     1     1  7.238425
# 4909  4.122712  0.000000               1              1     1     1  7.228867
# 4910  3.923577  0.000000               1              1     1     1  7.015951
# ...

# %%
df.tail(2), ssstd.prev_avg
# Out:
# (              o     ratio  t_rolling_mean  t_rolling_std  tavg       tstd  \
#  4998  10.371932  1.260595               1       1.414670     1  28.408746
#  4999  10.384667  1.260595               1       1.412415     1  28.406878
#
#                 u           x         z        z1
#  4998  418.241509  419.140413  1.603154  6.302974
#  4999  418.246744  418.765038  1.564728  6.302974  , 402.51585948120982)
