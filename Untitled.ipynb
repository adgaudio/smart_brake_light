# %%
# %matplotlib notebook

import sys ; sys.path.append('..')
# %run streamstd.py
# %run -i algo1.py
# Out:
# <img src="data:image/png;base64,...">

# %%
f.axes[0].set_xlim(2000,3000)

f

# %%
st.norm.cdf(1)

# %%
df.head(100)
# Out:
#             o     ratio  t_rolling_mean  t_rolling_std  tavg  tstd         u  \
# 0    0.145696  0.000000               1              1     1     1 -0.003596
# 1    0.349991  0.000000               1              1     1     1 -0.011410
# 2    4.977306  0.000000               1              1     1     1 -0.020055
# 3    6.131973  0.000000               1              1     1     1 -0.033722
# 4    7.068079  0.000000               1              1     1     1 -0.049669
# 5    7.593485  0.000000               1              1     1     1 -0.065667
# 6    7.939257  0.000000               1              1     1     1 -0.081710
# 7    8.582779  0.000000               1              1     1     1 -0.101448
# 8    9.133744  0.000000               1              1     1     1 -0.122083
# 9    9.738128  0.000000               1              1     1     1 -0.144818
# 10  10.001651  0.000000               1              1     1     1 -0.173571
# ...

# %%
df.sum(1)
# Out:
# 0        32.435075
# 1        -5.006492
# 2         1.392671
# 3         1.176859
# 4        -0.418717
# 5        -0.769168
# 6         0.559333
# 7         2.818184
# 8         0.834471
# 9         1.070561
# 10        3.643895
# 11        4.670303
# 12        5.834075
# 13        6.334365
# 14        7.067513
# 15        5.769698
# 16        5.253069
# 17        4.038456
# 18        5.539327
# 19        6.836985
# 20        7.330770
# 21        9.148127
# 22        7.950490
# 23        9.388985
# 24       10.553822
# 25       10.422842
# 26       10.282162
# 27       11.706034
# 28       11.073407
# 29       12.562214
#            ...
# 9970    234.546400
# 9971    235.401866
# 9972    235.249987
# 9973    235.764729
# 9974    235.688364
# 9975    234.796911
# 9976    235.030254
# 9977    234.798161
# 9978    235.275505
# 9979    234.236243
# 9980    234.124855
# 9981    233.593405
# 9982    234.555011
# 9983    235.186505
# 9984    234.370508
# 9985    235.543007
# ...
